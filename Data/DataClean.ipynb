# %%
# %pip install pandas scikit-learn pyarabic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (1.1.3)
# Collecting pyarabic
#   Using cached PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.3.2 in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.0.0 in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/roamsaleh/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: six>=1.14.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from pyarabic) (1.15.0)
# Using cached PyArabic-0.6.15-py3-none-any.whl (126 kB)
# Installing collected packages: pyarabic
# Successfully installed pyarabic-0.6.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
from pyarabic import araby
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("dataset.csv")

# %% [markdown]
# ### Arabic Normalization Function

# %%
def NormalizeArabic(text):
    text = text.strip()
    text = re.sub("ى", "ي", text)
    text = re.sub("ؤ", "ء", text)
    text = re.sub("ئ", "ء", text)

    text = re.sub("[إأٱآا]", "ا", text)

    text = re.sub("ة", "ه", text)

    text = re.sub(r"(.)\1+", r"\1\1", text)

    text = araby.strip_tashkeel(text)
    text = araby.strip_diacritics(text)

    text = re.sub('\s+', ' ', text)
    return text.strip()

# %% [markdown]
# ### Remove Punctuation

# %%
def RemovePunctuation(text):
     text = re.sub('[%s]' % re.escape("""!"#$%&'()*+,،-./:;<=>؟?@[\]^_`{|}~"""), ' ', text)
     text = re.sub('\s+', ' ', text)

     return text.strip()

# %% [markdown]
# ### Cleaning Function

# %%
def CleanText(text):
    text = NormalizeArabic(text)
    text = RemovePunctuation(text)
    return text

# %% [markdown]
# ### add it to the data

# %%
data["sentence"] = data["sentence"].apply(CleanText)

# %%
print(data.head())
print(data["label"].value_counts())

# %% [markdown]
# ### Split Dataset (Train / Validation / Test)
# - 70% train
# - 15% validation
# - 15% test

# %%
train_df, temp_df = train_test_split(
    data,
    test_size=0.30,
    stratify=data["label"],
    random_state=42
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    stratify=temp_df["label"],
    random_state=42
)

# %%
print("Train size:", len(train_df))
print("Validation size:", len(val_df))
print("Test size:", len(test_df))

# %% [markdown]
# ### save the dataset

# %%
train_df.to_csv("train.csv", index=False)

val_df.to_csv("validation.csv", index=False)

test_df.to_csv("test.csv", index=False)
